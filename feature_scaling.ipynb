# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('titanic_train.csv')

# %%
train['Age'] = train['Age'].fillna(train['Age'].median())

# %% [markdown]
# #### standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train['Age_scaled'] = scaler.fit_transform(train[['Age']])
train['Age_scaled'].head()
# Out:
# 0   -0.565736
# 1    0.663861
# 2   -0.258337
# 3    0.433312
# 4    0.433312
# Name: Age_scaled, dtype: float64

# %%
train['Age_scaled'].mean()
# Out:
# np.float64(1.0005616400330457)

# %%
train['Age_scaled'].std()
# Out:
# np.float64(1.0005616400330457)

# %% [markdown]
# #### normalisation

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train['Age_normalized'] = scaler.fit_transform(train[['Age']])
train['Age_normalized'].head()
# Out:
# 0    0.271174
# 1    0.472229
# 2    0.321438
# 3    0.434531
# 4    0.434531
# Name: Age_normalized, dtype: float64

# %%
train['Age_normalized'].max()
# Out:
# np.float64(1.0)

# %%
train['Age_normalized'].min()
# Out:
# np.float64(0.0)
